# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiamahmed26/Bioinformatics/blob/main/Bioinformatics_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.11/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []             Bemisia tabaci
# 8                []  Leptinotarsa decemlineata
# 9                []     Nephotettix cincticeps
# 10               []              Gallus gallus
# 11               []                Danio rerio
# 12               []            Musca domestica
# 13               []          Anopheles gambiae
# 14               []               Homo sapiens
# 15               []        Plutella xylostella
# 16               []            Musca domestica
# 17               []  Pediculus humanus capitis
# 18               []          Spodoptera litura
# 19               []      Laodelphax striatella
# 20               []        Schizaphis graminum
# 21               []              Aedes aegypti
# 22               []          Rattus norvegicus
# 23               []     Caenorhabditis elegans
# 24               []             Equus caballus
# 25               []     Canis lupus familiaris
# 26               []               Mus musculus
# 27               []          Rattus norvegicus
# 28               []             Equus caballus
# 29               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                               AChE2   16.0
# 8                                Acetylcholinesterase   16.0
# 9                Ace-orthologous acetylcholinesterase   16.0
# 10                               Acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                       Cholinesterases; ACHE & BCHE   15.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 23                             Acetylcholinesterase 1   14.0
# 24                              Butyrylcholinesterase   11.0
# 25                                     Cholinesterase   11.0
# 26                              Butyrylcholinesterase   10.0
# 27                              Butyrylcholinesterase   10.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase    8.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2366409
# 8                False    CHEMBL2366490
# 9                False    CHEMBL2366514
# 10               False    CHEMBL3227914
# 11               False    CHEMBL3308995
# 12               False       CHEMBL5752
# 13               False    CHEMBL2046266
# 14               False    CHEMBL2095233
# 15               False    CHEMBL2242729
# 16               False    CHEMBL2242743
# 17               False    CHEMBL2362988
# 18               False    CHEMBL2366422
# 19               False    CHEMBL2366446
# 20               False    CHEMBL2366511
# 21               False    CHEMBL4295607
# 22               False    CHEMBL2111475
# 23               False    CHEMBL3341583
# 24               False       CHEMBL5077
# 25               False    CHEMBL4630814
# 26               False       CHEMBL2528
# 27               False       CHEMBL3403
# 28               False       CHEMBL5763
# 29               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 15  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 24  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7038
# 8     7539
# 9    94400
# 10    9031
# 11    7955
# 12    7370
# 13    7165
# 14    9606
# 15   51655
# 16    7370
# 17  121226
# 18   69820
# 19  195883
# 20   13262
# 21    7159
# 22   10116
# 23    6239
# 24    9796
# 25    9615
# 26   10090
# 27   10116
# 28    9796
# 29    9606

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9412  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9413                                               None             None
# 9414                                               None             None
#
#       activity_id                                activity_properties  \
# 0           33969                                                 []
# 1           37563                                                 []
# 2           37565                                                 []
# 3           38902                                                 []
# 4           41170                                                 []
# ...           ...                                                ...
# 9410     25724873  [{'comments': None, 'relation': '=', 'result_f...
# 9411     25724874  [{'comments': None, 'relation': '=', 'result_f...
# 9412     25733694  [{'comments': None, 'relation': '=', 'result_f...
# 9413     25733695  [{'comments': None, 'relation': '=', 'result_f...
# 9414     25733696  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4       CHEMBL643384  Inhibitory concentration against acetylcholine...
# ...              ...                                                ...
# 9410   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9411   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9412   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9413   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9414   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 9410          B                    None                   None  BAO_0000190
# 9411          B                    None                   None  BAO_0000190
# 9412          B                    None                   None  BAO_0000190
# 9413          B                    None                   None  BAO_0000190
# 9414          B                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 9410  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9411  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9412  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9413  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9414  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type units    uo_units upper_value  value
# 0     None  IC50    uM  UO_0000065        None   0.75
# 1     None  IC50    uM  UO_0000065        None    0.1
# 2     None  IC50    uM  UO_0000065        None   50.0
# 3     None  IC50    uM  UO_0000065        None    0.3
# 4     None  IC50    uM  UO_0000065        None    0.8
# ...    ...   ...   ...         ...         ...    ...
# 9410  None  IC50    uM  UO_0000065        None   46.0
# 9411  None  IC50    uM  UO_0000065        None  38.31
# 9412  None  IC50    uM  UO_0000065        None   1.71
# 9413  None  IC50    uM  UO_0000065        None   10.0
# 9414  None  IC50    uM  UO_0000065        None   10.0
#
# [9415 rows x 46 columns]

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-23-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9412  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9413                                               None             None
# 9414                                               None             None
#
#       activity_id                                activity_properties  \
# 0           33969                                                 []
# 1           37563                                                 []
# 2           37565                                                 []
# 3           38902                                                 []
# 4           41170                                                 []
# ...           ...                                                ...
# 9410     25724873  [{'comments': None, 'relation': '=', 'result_f...
# 9411     25724874  [{'comments': None, 'relation': '=', 'result_f...
# 9412     25733694  [{'comments': None, 'relation': '=', 'result_f...
# 9413     25733695  [{'comments': None, 'relation': '=', 'result_f...
# 9414     25733696  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4       CHEMBL643384  Inhibitory concentration against acetylcholine...
# ...              ...                                                ...
# 9410   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9411   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9412   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9413   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9414   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 9410          B                    None                   None  BAO_0000190
# 9411          B                    None                   None  BAO_0000190
# 9412          B                    None                   None  BAO_0000190
# 9413          B                    None                   None  BAO_0000190
# 9414          B                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 9410  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9411  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9412  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9413  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9414  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type units    uo_units upper_value  value
# 0     None  IC50    uM  UO_0000065        None   0.75
# 1     None  IC50    uM  UO_0000065        None    0.1
# 2     None  IC50    uM  UO_0000065        None   50.0
# 3     None  IC50    uM  UO_0000065        None    0.3
# 4     None  IC50    uM  UO_0000065        None    0.8
# ...    ...   ...   ...         ...         ...    ...
# 9410  None  IC50    uM  UO_0000065        None   46.0
# 9411  None  IC50    uM  UO_0000065        None  38.31
# 9412  None  IC50    uM  UO_0000065        None   1.71
# 9413  None  IC50    uM  UO_0000065        None   10.0
# 9414  None  IC50    uM  UO_0000065        None   10.0
#
# [8128 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 6642

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9412  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9413                                               None             None
# 9414                                               None             None
#
#       activity_id                                activity_properties  \
# 0           33969                                                 []
# 1           37563                                                 []
# 2           37565                                                 []
# 3           38902                                                 []
# 4           41170                                                 []
# ...           ...                                                ...
# 9410     25724873  [{'comments': None, 'relation': '=', 'result_f...
# 9411     25724874  [{'comments': None, 'relation': '=', 'result_f...
# 9412     25733694  [{'comments': None, 'relation': '=', 'result_f...
# 9413     25733695  [{'comments': None, 'relation': '=', 'result_f...
# 9414     25733696  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3       CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4       CHEMBL643384  Inhibitory concentration against acetylcholine...
# ...              ...                                                ...
# 9410   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9411   CHEMBL5391657  Inhibition of Acetylcholinesterase (unknown or...
# 9412   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9413   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
# 9414   CHEMBL5393547  Inhibition of recombinant human AChE expressed...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 9410          B                    None                   None  BAO_0000190
# 9411          B                    None                   None  BAO_0000190
# 9412          B                    None                   None  BAO_0000190
# 9413          B                    None                   None  BAO_0000190
# 9414          B                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 9410  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9411  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9412  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9413  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 9414  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type units    uo_units upper_value  value
# 0     None  IC50    uM  UO_0000065        None   0.75
# 1     None  IC50    uM  UO_0000065        None    0.1
# 2     None  IC50    uM  UO_0000065        None   50.0
# 3     None  IC50    uM  UO_0000065        None    0.3
# 4     None  IC50    uM  UO_0000065        None    0.8
# ...    ...   ...   ...         ...         ...    ...
# 9410  None  IC50    uM  UO_0000065        None   46.0
# 9411  None  IC50    uM  UO_0000065        None  38.31
# 9412  None  IC50    uM  UO_0000065        None   1.71
# 9413  None  IC50    uM  UO_0000065        None   10.0
# 9414  None  IC50    uM  UO_0000065        None   10.0
#
# [6642 rows x 46 columns]

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 9410      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 9411        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 9412      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 9413      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 9414      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#      standard_value
# 0             750.0
# 1             100.0
# 2           50000.0
# 3             300.0
# 4             800.0
# ...             ...
# 9410        46000.0
# 9411        38310.0
# 9412         1710.0
# 9413        10000.0
# 9414        10000.0
#
# [6642 rows x 3 columns]

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#       standard_value         class
# 0              750.0        active
# 1              100.0        active
# 2            50000.0      inactive
# 3              300.0        active
# 4              800.0        active
# ...              ...           ...
# 6637         46000.0      inactive
# 6638         38310.0      inactive
# 6639          1710.0  intermediate
# 6640         10000.0      inactive
# 6641         10000.0      inactive
#
# [6642 rows x 4 columns]

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 7044
# -rw-r--r-- 1 root root 5493157 Feb 20 16:32 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  487585 Feb 20 16:32 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  548522 Feb 20 16:32 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  669854 Feb 20 16:32 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 Feb 18 14:20 sample_data

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-02-20 16:32:40--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   134MB/s    in 0.6s
#
# 2025-02-20 16:32:41 (134 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.4           |   py37hce1f21e_0         126 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2024.12.31 |       h06a4308_0         128 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     fontconfig-2.13.0          |       h9420a91_0         227 KB
#     freetype-2.11.0            |       h70c0345_0         618 KB
#     glib-2.63.1                |       h5a9c865_0         2.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     jpeg-9e                    |       h7f8727e_0         240 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     libboost-1.67.0            |       h46d08c1_4        13.0 MB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.1.0              |       h2733197_0         447 KB
#     libuuid-1.0.3              |       h7f8727e_2          17 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxml2-2.9.9              |       hea5a465_1         1.6 MB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     numexpr-2.8.1              |   py37h6abb31d_0         123 KB
#     numpy-1.21.5               |   py37he7a7128_2          10 KB
#     numpy-base-1.21.5          |   py37hf524024_2         4.8 MB
#     olefile-0.46               |           py37_0          50 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     packaging-22.0             |   py37h06a4308_0          68 KB
#     pandas-1.3.5               |   py37h8c16a72_0         9.3 MB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pillow-8.2.0               |   py37he98fc37_0         622 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     py-boost-1.67.0            |   py37h04863e7_4         278 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     pytz-2022.7                |   py37h06a4308_0         207 KB
#     rdkit-2020.03.3.0          |   py37hc20afe1_1        24.8 MB  rdkit
#     ruamel.yaml-0.16.12        |   py37h7b6447c_1         173 KB
#     ruamel.yaml.clib-0.2.6     |   py37h7f8727e_0         133 KB
#     toolz-0.12.0               |   py37h06a4308_0         104 KB
#     typing_extensions-4.4.0    |   py37h06a4308_0          45 KB
#     zipp-3.11.0                |   py37h06a4308_0          19 KB
#     zstd-1.3.7                 |       h0b5b093_0         401 KB
#     ------------------------------------------------------------
#                                            Total:       225.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.4-py37hce1f21e_0
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.14.12-h8948797_3
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyhd3eb1b0_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.0-h9420a91_0
#   freetype           pkgs/main/linux-64::freetype-2.11.0-h70c0345_0
#   glib               pkgs/main/linux-64::glib-2.63.1-h5a9c865_0
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   jpeg               pkgs/main/linux-64::jpeg-9e-h7f8727e_0
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   libboost           pkgs/main/linux-64::libboost-1.67.0-h46d08c1_4
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_0
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h7f8727e_2
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.9-hea5a465_1
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.1-py37h6abb31d_0
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37he7a7128_2
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37hf524024_2
#   olefile            pkgs/main/linux-64::olefile-0.46-py37_0
#   packaging          pkgs/main/linux-64::packaging-22.0-py37h06a4308_0
#   pandas             pkgs/main/linux-64::pandas-1.3.5-py37h8c16a72_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pillow             pkgs/main/linux-64::pillow-8.2.0-py37he98fc37_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   py-boost           pkgs/main/linux-64::py-boost-1.67.0-py37h04863e7_4
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   pytz               pkgs/main/linux-64::pytz-2022.7-py37h06a4308_0
#   rdkit              rdkit/linux-64::rdkit-2020.03.3.0-py37hc20afe1_1
#   ruamel.yaml        pkgs/main/linux-64::ruamel.yaml-0.16.12-py37h7b6447c_1
#   ruamel.yaml.clib   pkgs/main/linux-64::ruamel.yaml.clib-0.2.6-py37h7f8727e_0
#   toolz              pkgs/main/linux-64::toolz-0.12.0-py37h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.4.0-py37h06a4308_0
#   zipp               pkgs/main/linux-64::zipp-3.11.0-py37h06a4308_0
#   zstd               pkgs/main/linux-64::zstd-1.3.7-h0b5b093_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2024.12.31-h06a4308_0
#   certifi                                 2019.11.28-py37_0 --> 2022.12.7-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 23.1.0-py37h06a4308_0
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1w-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# bottleneck-1.3.4     | 126 KB    | : 100% 1.0/1 [00:00<00:00,  4.61it/s]
# pixman-0.40.0        | 373 KB    | : 100% 1.0/1 [00:00<00:00,  6.06it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  2.50it/s]
# typing_extensions-4. | 45 KB     | : 100% 1.0/1 [00:00<00:00,  6.53it/s]
# ruamel.yaml.clib-0.2 | 133 KB    | : 100% 1.0/1 [00:00<00:00,  6.68it/s]
# cairo-1.14.12        | 906 KB    | : 100% 1.0/1 [00:00<00:00,  5.79it/s]
# numpy-1.21.5         | 10 KB     | : 100% 1.0/1 [00:00<00:00,  6.60it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00,  6.82it/s]
# rdkit-2020.03.3.0    | 24.8 MB   | : 100% 1.0/1 [00:04<00:00,  4.57s/it]
# numexpr-2.8.1        | 123 KB    | : 100% 1.0/1 [00:00<00:00,  5.86it/s]
# libboost-1.67.0      | 13.0 MB   | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
# pandas-1.3.5         | 9.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.88it/s]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00,  6.56it/s]
# openssl-1.1.1w       | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.84it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  6.58it/s]
# zipp-3.11.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00,  6.17it/s]
# jpeg-9e              | 240 KB    | : 100% 1.0/1 [00:00<00:00,  6.76it/s]
# ruamel.yaml-0.16.12  | 173 KB    | : 100% 1.0/1 [00:00<00:00,  5.92it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00,  6.94it/s]
# fontconfig-2.13.0    | 227 KB    | : 100% 1.0/1 [00:00<00:00,  6.03it/s]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00,  6.53it/s]
# zstd-1.3.7           | 401 KB    | : 100% 1.0/1 [00:00<00:00,  6.29it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00,  6.63it/s]
# ca-certificates-2024 | 128 KB    | : 100% 1.0/1 [00:00<00:00,  6.76it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00,  7.07it/s]
# libtiff-4.1.0        | 447 KB    | : 100% 1.0/1 [00:00<00:00,  6.39it/s]
# olefile-0.46         | 50 KB     | : 100% 1.0/1 [00:00<00:00,  6.92it/s]
# py-boost-1.67.0      | 278 KB    | : 100% 1.0/1 [00:00<00:00,  6.18it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:06<00:00,  6.44s/it]
# conda-23.1.0         | 937 KB    | : 100% 1.0/1 [00:00<00:00,  5.28it/s]
# libuuid-1.0.3        | 17 KB     | : 100% 1.0/1 [00:00<00:00,  7.19it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00,  6.95it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.42it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# python-dateutil-2.8. | 233 KB    | : 100% 1.0/1 [00:00<00:00,  5.01it/s]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00,  6.98it/s]
# glib-2.63.1          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# pytz-2022.7          | 207 KB    | : 100% 1.0/1 [00:00<00:00,  5.52it/s]
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  6.23it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00,  6.78it/s]
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00,  6.72it/s]
# freetype-2.11.0      | 618 KB    | : 100% 1.0/1 [00:00<00:00,  5.55it/s]
# flit-core-3.6.0      | 42 KB     | : 100% 1.0/1 [00:00<00:00,  6.72it/s]
# packaging-22.0       | 68 KB     | : 100% 1.0/1 [00:00<00:00,  6.44it/s]
# pillow-8.2.0         | 622 KB    | : 100% 1.0/1 [00:00<00:00,  6.14it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00,  6.81it/s]
# toolz-0.12.0         | 104 KB    | : 100% 1.0/1 [00:00<00:00,  6.75it/s]
# libxml2-2.9.9        | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.88it/s]
# done
# done
# done

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_03_bioactivity_data_curated.csv
# Out:
# --2025-02-20 16:33:58--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_03_bioactivity_data_curated.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385924 (377K) [text/plain]
# Saving to: ‘acetylcholinesterase_03_bioactivity_data_curated.csv.1’
#
# acetylcholinesteras 100%[===================>] 376.88K  --.-KB/s    in 0.04s
#
# 2025-02-20 16:33:59 (8.23 MB/s) - ‘acetylcholinesterase_03_bioactivity_data_curated.csv.1’ saved [385924/385924]

# %%
import pandas as pd

# %%
df = pd.read_csv('acetylcholinesterase_03_bioactivity_data_curated.csv')
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#       standard_value         class
# 0              750.0        active
# 1              100.0        active
# 2            50000.0      inactive
# 3              300.0        active
# 4              800.0        active
# ...              ...           ...
# 6637         46000.0      inactive
# 6638         38310.0      inactive
# 6639          1710.0  intermediate
# 6640         10000.0      inactive
# 6641         10000.0      inactive
#
# [6642 rows x 4 columns]

# %%
df_no_smiles = df.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#      molecule_chembl_id  standard_value         class  \
# 0          CHEMBL133897           750.0        active
# 1          CHEMBL336398           100.0        active
# 2          CHEMBL131588         50000.0      inactive
# 3          CHEMBL130628           300.0        active
# 4          CHEMBL130478           800.0        active
# ...                 ...             ...           ...
# 6637      CHEMBL5398421         46000.0      inactive
# 6638        CHEMBL11298         38310.0      inactive
# 6639      CHEMBL5395312          1710.0  intermediate
# 6640      CHEMBL5399112         10000.0      inactive
# 6641      CHEMBL5402411         10000.0      inactive
#
#                                        canonical_smiles
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4             CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                                                 ...
# 6637            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638                                  N[C@@H](CO)C(=O)O
# 6639  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
# [6642 rows x 4 columns]

# %%
! conda create -c conda-forge -n my-rdkit-env rdkit
! conda activate my-rdkit-env
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate my-rdkit-env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda install -c conda-forge rdkit boost -y
# !conda install -c conda-forge python=3.9 -y
# !pip install rdkit
import rdkit
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.1.1
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - boost
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-1.68.0               |py37h8619c78_1001         310 KB  conda-forge
#     boost-cpp-1.68.0           |    h11c811c_1000        20.5 MB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        21.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost              conda-forge/linux-64::boost-1.68.0-py37h8619c78_1001
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.68.0-h11c811c_1000
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.12.31~ --> conda-forge::ca-certificates-2025.1.31-hbcca054_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# certifi-2024.2.2     | 157 KB    | :   0% 0/1 [00:00<?, ?it/s]
# boost-cpp-1.68.0     | 20.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2024.2.2     | 157 KB    | :  10% 0.10204348557228184/1 [00:00<00:01,  1.37s/it]
# boost-cpp-1.68.0     | 20.5 MB   | :   0% 0.0007606837908424146/1 [00:00<03:08, 188.84s/it]
#
# boost-1.68.0         | 310 KB    | :   5% 0.0516395819412751/1 [00:00<00:02,  3.09s/it]
# boost-cpp-1.68.0     | 20.5 MB   | :  26% 0.25939317267726336/1 [00:00<01:37, 132.30s/it]
# certifi-2024.2.2     | 157 KB    | : 100% 1.0/1 [00:00<00:00,  1.04s/it]
# boost-cpp-1.68.0     | 20.5 MB   | : 100% 0.9995385011669328/1 [00:00<00:00, 65.04s/it]
#
# boost-1.68.0         | 310 KB    | : 100% 1.0/1 [00:00<00:00,  2.26s/it]
#
# boost-1.68.0         | 310 KB    | : 100% 1.0/1 [00:00<00:00,  2.26s/it]
# boost-cpp-1.68.0     | 20.5 MB   | : 100% 1.0/1 [00:06<00:00, 65.04s/it]
#
#
#
#
# done
# done
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (python):
#
#   - python=3.9
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package tk conflicts for:
# asn1crypto -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.5.*|>=8.6.14,<8.7.0a0']
# conda[version='>=23.1.0'] -> python[version='>=3.13,<3.14.0a0'] -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-package-handling -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bottleneck -> python[version='>=3.13,<3.14.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytz -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# boost -> pypy3.9[version='>=7.3.15'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tk
# pycosat -> python[version='>=3.12,<3.13.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wheel -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# idna -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# olefile -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python=3.9 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0']
# urllib3 -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zipp -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# packaging -> python[version='>=3.8'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pluggy -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ruamel.yaml -> python[version='>=3.13,<3.14.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cryptography -> python[version='>=3.12,<3.13.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ruamel_yaml -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# py-boost -> python[version='>=3.12,<3.13.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_fft -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# flit-core -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib-metadata -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# glib -> python= -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.14,<8.7.0a0']
# cffi -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pandas -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpy -> python[version='>=3.13,<3.14.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pysocks -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tqdm -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# chardet -> python[version='>=3.12,<3.13.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# certifi -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pycparser -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-dateutil -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ruamel.yaml.clib -> python[version='>=3.12,<3.13.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# six -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# setuptools -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# toolz -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# typing_extensions -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numexpr -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyopenssl -> python[version='>=3.9'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# rdkit -> matplotlib-base -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.12,<8.7|>=8.6.11,<8.7|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.14,<8.7.0a0']
# numpy-base -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.5.*|8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.13,<8.7.0a0|>=8.6.14,<8.7.0a0|>=8.6.9,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package libmpdec conflicts for:
# zipp -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# cryptography -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# packaging -> python[version='>=3.8'] -> libmpdec[version='>=4.0.0,<5.0a0']
# toolz -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# olefile -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# glib -> python= -> libmpdec[version='>=4.0.0,<5.0a0']
# idna -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# mkl-service -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# typing_extensions -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# importlib-metadata -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pluggy -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pandas -> python[version='>=3.13.0rc2,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# requests -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# importlib_metadata -> python -> libmpdec[version='>=4.0.0,<5.0a0']
# ruamel.yaml.clib -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# ruamel.yaml -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pytz -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# wheel -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pysocks -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# asn1crypto -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pip -> python[version='>=3.13.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# certifi -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# numpy-base -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pycosat -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# ruamel_yaml -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# setuptools -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# six -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# bottleneck -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# flit-core -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pycparser -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# mkl_random -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# conda-package-handling -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# rdkit -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# tqdm -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# conda[version='>=23.1.0'] -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# python-dateutil -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# urllib3 -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# numpy -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pyopenssl -> python[version='>=3.9'] -> libmpdec[version='>=4.0.0,<5.0a0']
# mkl_fft -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# pillow -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# numexpr -> python[version='>=3.13,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# chardet -> python[version='>=3.13.0rc1,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
# cffi -> python[version='>=3.13.0rc1,<3.14.0a0'] -> libmpdec[version='>=4.0.0,<5.0a0']
#
# Package _libgcc_mutex conflicts for:
# conda-package-handling -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libboost -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# yaml -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# _libgcc_mutex
# bottleneck -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libstdcxx-ng -> libgcc-ng==14.1.0=h77fa898_0 -> _libgcc_mutex==0.1=conda_forge
# bzip2 -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# blas -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libxcb -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# ruamel.yaml -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# numpy -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libffi -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# zstd -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# ncurses -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libpng -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1|0.1',build='main|main|conda_forge']
# sqlite -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# numpy-base -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# boost-cpp -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# mkl -> _openmp_mutex=[build=*_llvm] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# rdkit -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libtiff -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# fontconfig -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libuuid -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# mkl_random -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# pycosat -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# pcre -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# cffi -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# cryptography -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# pandas -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# glib -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# numexpr -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# jpeg -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# ruamel_yaml -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# readline -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# mkl-service -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# mkl_fft -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# pillow -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# icu -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# zlib -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# cairo -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libxml2 -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# xz -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1|0.1',build='main|main|conda_forge']
# tk -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# libgcc-ng -> _libgcc_mutex[version='*|0.1|0.1',build='main|main|conda_forge']
# libedit -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1|0.1',build='main|main|conda_forge']
# boost -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# freetype -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# lcms2 -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# ruamel.yaml.clib -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# py-boost -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# openssl -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# pixman -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1|0.1',build='main|main|conda_forge']
# intel-openmp -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# python=3.9 -> libgcc[version='>=13'] -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
#
# Package libstdcxx conflicts for:
# pandas -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# libtiff -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# pandas -> libstdcxx[version='>=13']
# pillow -> libtiff[version='>=4.7.0,<4.8.0a0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# zstd -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# pcre -> libstdcxx-ng[version='>=9.3.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# freetype -> libstdcxx-ng[version='>=4.9'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# blas -> mkl -> libstdcxx[version='>=13']
# mkl -> libstdcxx[version='>=13']
# icu -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# sqlite -> libstdcxx-ng[version='>=7.3.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# mkl -> tbb=2021 -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# pixman -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# mkl_fft -> numpy[version='>=1.19,<3'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# python=3.9 -> libstdcxx-ng[version='>=9.3.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# yaml -> libstdcxx-ng[version='>=7.3.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# libboost -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# boost-cpp -> zstd[version='>=1.5.6,<1.6.0a0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# ncurses -> libstdcxx-ng[version='>=7.5.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# numpy-base -> libstdcxx-ng[version='>=11.2.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# pixman -> libstdcxx[version='>=13']
# boost -> numpy[version='>=1.19,<3'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# rdkit -> libstdcxx[version='>=13']
# cairo -> libstdcxx[version='>=13']
# mkl_random -> libstdcxx[version='>=13']
# numpy -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# intel-openmp -> libstdcxx-ng[version='>=11.2.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# libffi -> libstdcxx-ng[version='>=9.4.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# bottleneck -> numpy[version='>=1.21,<3'] -> libstdcxx[version='>=13']
# libboost -> libstdcxx[version='>=13']
# py-boost -> libstdcxx-ng[version='>=11.2.0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# rdkit -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# urllib3 -> brotli-python[version='>=1.0.9'] -> libstdcxx[version='>=13']
# lcms2 -> libtiff[version='>=4.7.0,<4.8.0a0'] -> libstdcxx[version='>=13']
# libstdcxx-ng -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# libtiff -> libstdcxx[version='>=13']
# mkl_random -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# zstd -> libstdcxx[version='>=13']
# glib -> gettext[version='>=0.21.1,<1.0a0'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0|>=13',build=hc0a3c3a_1]
# numexpr -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# cairo -> libstdcxx-ng[version='>=12'] -> libstdcxx[version='12.4.0|13.3.0|14.1.0|14.2.0',build=hc0a3c3a_1]
# numexpr -> libstdcxx[version='>=13']
# numpy -> libstdcxx[version='>=13']
#
# Package ld_impl_linux-64 conflicts for:
# six -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# zipp -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# python=3.9 -> ld_impl_linux-64[version='>=2.36.1']
# pillow -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# mkl_fft -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# olefile -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# python-dateutil -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# tqdm -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# boost -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.36.1|>=2.35.1']
# setuptools -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.36.1|>=2.35.1']
# packaging -> python[version='>=3.8'] -> ld_impl_linux-64[version='>=2.34|>=2.36.1|>=2.35.1']
# bottleneck -> python[version='>=3.13,<3.14.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# ld_impl_linux-64
# toolz -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# numexpr -> python[version='>=3.11,<3.12.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pandas -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# numpy -> python[version='>=3.13,<3.14.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# ruamel_yaml -> python[version='>=3.10,<3.11.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pytz -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# flit-core -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pyopenssl -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# ruamel.yaml.clib -> python[version='>=3.12,<3.13.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# py-boost -> python[version='>=3.12,<3.13.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# ruamel.yaml -> python[version='>=3.13,<3.14.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# numpy-base -> python[version='>=3.10,<3.11.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# importlib-metadata -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# certifi -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# cffi -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# wheel -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# conda-package-handling -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# idna -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# urllib3 -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# chardet -> python[version='>=3.12,<3.13.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pycosat -> python[version='>=3.12,<3.13.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pysocks -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# glib -> python= -> ld_impl_linux-64[version='>=2.34|>=2.36.1|>=2.35.1']
# conda[version='>=23.1.0'] -> python[version='>=3.13,<3.14.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pluggy -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# requests -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# asn1crypto -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# typing_extensions -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# cryptography -> python[version='>=3.12,<3.13.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# rdkit -> python[version='>=3.11,<3.12.0a0'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
# pycparser -> python[version='>=3.9'] -> ld_impl_linux-64[version='>=2.34|>=2.35.1|>=2.36.1']
#
# Package libgcc-ng conflicts for:
# yaml -> libstdcxx-ng[version='>=7.3.0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# conda-package-handling -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=11.2.0']
# cryptography -> cffi[version='>=1.12'] -> libgcc-ng[version='>=11.2.0|>=13']
# libuuid -> libgcc-ng[version='>=11.2.0|>=12|>=9.3.0|>=7.3.0|>=7.5.0|>=7.2.0']
# libedit -> libgcc-ng[version='>=11.2.0|>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# icu -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# libxcb -> libgcc-ng[version='>=12|>=13|>=9.4.0|>=9.3.0|>=7.3.0|>=4.9|>=7.5.0|>=7.2.0']
# tk -> libzlib[version='>=1.2.11,<2.0.0a0'] -> libgcc-ng[version='>=10.3.0']
# mkl-service -> python[version='>=3.9,<3.10.0a0'] -> libgcc-ng[version='>=10.3.0|>=4.9']
# cairo -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# icu -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# libedit -> ncurses -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0']
# pycosat -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# sqlite -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# mkl_random -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=7.2.0']
# py-boost -> libstdcxx-ng[version='>=11.2.0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=12|>=10.3.0|>=9.4.0|>=9.3.0|>=4.9|>=13',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# libxml2 -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# xz -> libgcc-ng[version='>=11.2.0|>=12|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# rdkit -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0']
# libffi -> libstdcxx-ng[version='>=9.4.0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# boost -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0']
# mkl_fft -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# cffi -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# libstdcxx-ng -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# certifi -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# pycparser -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# numexpr -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# conda-package-handling -> python[version='>=3.7'] -> libgcc-ng[version='>=4.9|>=7.2.0']
# mkl_random -> numpy[version='>=1.19,<3'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=10.3.0|>=13|>=4.9',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# pandas -> numpy[version='>=1.19,<3'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# freetype -> libgcc-ng[version='>=11.2.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# intel-openmp -> libgcc-ng[version='>=11.2.0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=10.3.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# ncurses -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# python=3.9 -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0']
# numpy -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=14|>=14.1.0|>=13.3.0|>=13.2.0|>=12.4.0|>=12.3.0|>=11.4.0|>=8.2.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# numpy -> libgcc-ng[version='>=10.3.0|>=12|>=13|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# libtiff -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# pysocks -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=10.3.0']
# tqdm -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# ruamel.yaml.clib -> python[version='>=3.7,<3.8.0a0'] -> libgcc-ng[version='>=4.9|>=7.2.0']
# zstd -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# mkl -> libgcc-ng[version='>=11.2.0']
# jpeg -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=7.5.0|>=7.3.0|>=11.2.0|>=7.2.0']
# conda[version='>=23.1.0'] -> frozendict[version='>=2.4.2'] -> libgcc-ng[version='>=10.3.0|>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# pandas -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# six -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# bottleneck -> numpy[version='>=1.21,<3'] -> libgcc-ng[version='>=13']
# glib -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# libboost -> libgcc-ng[version='>=11.2.0|>=12|>=7.5.0|>=7.3.0|>=7.2.0']
# numexpr -> numpy[version='>=1.21,<3'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13|>=14|>=8.2.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=11.2.0|>=4.9|>=7.2.0']
# zstd -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# bzip2 -> libgcc-ng[version='>=11.2.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# fontconfig -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# zipp -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# libboost -> bzip2[version='>=1.0.8,<2.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=9.3.0|>=10.3.0|>=9.4.0|>=4.9',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# boost-cpp -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=11.2.0|>=7.2.0']
# boost-cpp -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=4.9',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# pillow -> libxcb[version='>=1.16,<2.0.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# libtiff -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=10.3.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# libgcc-ng
# asn1crypto -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# cryptography -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# pytz -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# chardet -> python[version='>=3.12,<3.13.0a0'] -> libgcc-ng[version='>=10.3.0|>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# libpng -> libgcc-ng[version='>=11.2.0|>=12|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# mkl_fft -> numpy[version='>=1.19,<3'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# zlib -> libgcc-ng[version='>=10.3.0|>=12|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0|>=7.2.0']
# pixman -> libstdcxx-ng[version='>=12'] -> libgcc-ng[version='12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11']
# pyopenssl -> cryptography[version='>=41.0.5,<45'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# ruamel.yaml -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=11.2.0']
# idna -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# yaml -> libgcc-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# pcre -> libgcc-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=7.2.0']
# pixman -> libgcc-ng[version='>=12|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# blas -> libgfortran5[version='>=13.3.0'] -> libgcc-ng[version='>=11.2.0|>=11.4.0|>=12.3.0|>=12.4.0|>=13.2.0|>=13.3.0|>=14.1.0|>=14|>=4.9']
# readline -> libgcc-ng[version='>=11.2.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# py-boost -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0|>=7.2.0']
# lcms2 -> jpeg[version='>=9e,<10a'] -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=7.2.0']
# sqlite -> libstdcxx-ng[version='>=7.3.0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# packaging -> python[version='>=3.8'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=11.2.0|>=4.9|>=7.2.0']
# flit-core -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# ruamel_yaml -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# ruamel_yaml -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=10.3.0']
# cairo -> libxcb[version='>=1.16,<1.17.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# glib -> python= -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=10.3.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# mkl-service -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=7.2.0']
# rdkit -> freetype[version='>=2.12.1,<3.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=11.2.0|>=13|>=4.9|>=7.2.0|>=8.4.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# urllib3 -> brotli-python[version='>=1.0.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# mkl -> tbb=2021 -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=10.3.0|>=12|>=13|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# libffi -> libgcc-ng[version='>=11.2.0|>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# setuptools -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# python=3.9 -> openssl[version='>=3.2.1,<4.0a0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0|>=13|>=4.9|>=7.2.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# pcre -> libstdcxx-ng[version='>=9.3.0'] -> libgcc-ng[version='11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|11.4.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.3.0|12.4.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.2.0|13.3.0|14.1.0',build='h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_0|h77fa898_8|h77fa898_9|h77fa898_10|h77fa898_11|h77fa898_0|h77fa898_13|h77fa898_12|h77fa898_13|h77fa898_12|h77fa898_11|h77fa898_13|h77fa898_12|h77fa898_11']
# requests -> python[version='>=3.9'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=11.2.0|>=7.3.0|>=4.9|>=7.2.0']
# tk -> libgcc-ng[version='>=11.2.0|>=12|>=9.4.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# ...
#
# Package py-boost conflicts for:
# rdkit -> boost -> py-boost[version='1.65.1|1.65.1|1.65.1|1.67.0|1.67.0|1.67.0|1.67.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.82.0',build='py36hff4598c_3|py37h04863e7_4|py38h962f231_0|py36h0573a6f_0|py310h00e6091_0|py37h51133e4_1|py310h00e6091_1|py37h962f231_10|py38h962f231_10|py36h962f231_11|py37h962f231_11|py38ha9443f7_11|py36ha9443f7_11|py39ha9443f7_11|py37h51133e4_12|py39h3c18c91_0|py38h3c18c91_0|py310h3c18c91_0|py310h3c18c91_1|py39h3c18c91_1|py311h4cb112f_1|py39h3c18c91_2|py38h3c18c91_2|py312h6db74b5_2|py311h4cb112f_2|py310h3c18c91_2|py38h3c18c91_1|py311h4cb112f_0|py310h00e6091_12|py39h51133e4_12|py38h51133e4_12|py37ha9443f7_11|py38h962f231_11|py36h962f231_10|py38h51133e4_1|py39h51133e4_1|py37h0573a6f_0|py35h04863e7_4|py36h04863e7_4|py27h04863e7_4|py27h3b928e7_3|py35hdf000e1_3']
# rdkit -> py-boost
# boost -> py-boost[version='1.65.1|1.65.1|1.65.1|1.67.0|1.67.0|1.67.0|1.67.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.71.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.73.0|1.82.0',build='py36hff4598c_3|py37h04863e7_4|py38h962f231_0|py36h0573a6f_0|py310h00e6091_0|py37h51133e4_1|py310h00e6091_1|py37h962f231_10|py38h962f231_10|py36h962f231_11|py37h962f231_11|py38ha9443f7_11|py36ha9443f7_11|py39ha9443f7_11|py37h51133e4_12|py39h3c18c91_0|py38h3c18c91_0|py310h3c18c91_0|py310h3c18c91_1|py39h3c18c91_1|py311h4cb112f_1|py39h3c18c91_2|py38h3c18c91_2|py312h6db74b5_2|py311h4cb112f_2|py310h3c18c91_2|py38h3c18c91_1|py311h4cb112f_0|py310h00e6091_12|py39h51133e4_12|py38h51133e4_12|py37ha9443f7_11|py38h962f231_11|py36h962f231_10|py38h51133e4_1|py39h51133e4_1|py37h0573a6f_0|py35h04863e7_4|py36h04863e7_4|py27h04863e7_4|py27h3b928e7_3|py35hdf000e1_3']
# py-boost
#
# Package mkl-service conflicts for:
# rdkit -> numpy[version='>=1.19,<3'] -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# numexpr -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# numpy -> mkl_fft -> mkl-service
# mkl_fft -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# pandas -> numpy[version='>=1.19,<3'] -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# numpy -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# boost -> numpy[version='>=1.19,<3'] -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# py-boost -> numpy[version='>=1.21.2,<2.0a0'] -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# mkl-service
# bottleneck -> numpy[version='>=1.21,<3'] -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# mkl_random -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
# numpy-base -> mkl-service[version='>=2,<3.0a0|>=2.3.0,<3.0a0']
#
# Package xorg-libxau conflicts for:
# cairo -> libxcb[version='>=1.17.0,<2.0a0'] -> xorg-libxau[version='>=1.0.11,<2.0a0']
# libxcb -> xorg-libxau[version='>=1.0.11,<2.0a0']
# pillow -> libxcb[version='>=1.17.0,<2.0a0'] -> xorg-libxau[version='>=1.0.11,<2.0a0']
#
# Package ipaddress conflicts for:
# urllib3 -> ipaddress
# pyopenssl -> cryptography[version='>=2.8,<39.0a0'] -> ipaddress
# requests -> urllib3[version='>=1.21.1,<3'] -> ipaddress
# cryptography -> ipaddress
#
# Package ruamel.yaml conflicts for:
# conda[version='>=23.1.0'] -> ruamel.yaml[version='>=0.11.14,<0.18|>=0.11.14,<0.19']
# ruamel.yaml
#
# Package pandas conflicts for:
# pandas
# rdkit -> pandas[version='<2.2']
#
# Package contextlib2 conflicts for:
# importlib_metadata -> contextlib2
# importlib-metadata -> contextlib2
# pluggy -> importlib_metadata[version='>=0.12'] -> contextlib2
#
# Package libtiff conflicts for:
# libtiff
# lcms2 -> libtiff[version='>=4.0.10,<4.5.0a0|>=4.1.0,<4.5.0a0|>=4.2.0,<4.5.0a0|>=4.4.0,<4.5.0a0|>=4.5.0,<4.6.0a0|>=4.6.0,<4.8.0a0|>=4.7.0,<4.8.0a0|>=4.5.1,<5.0a0|>=4.1.0,<5.0a0']
# rdkit -> pillow -> libtiff[version='4.*|4.0.*|>=4.0.10,<4.4.0a0|>=4.1.0,<4.4.0a0|>=4.2.0,<4.4.0a0|>=4.3.0,<4.4.0a0|>=4.3.0,<4.5.0a0|>=4.4.0,<4.5.0a0|>=4.5.0,<4.6.0a0|>=4.5.1,<4.6.0a0|>=4.6.0,<4.8.0a0|>=4.7.0,<4.8.0a0|>=4.0.9,<4.4.0a0|>=4.0.8,<4.0.10|>=4.0.3,<4.0.8|4.0.6|>=4.2.0,<5.0a0|>=4.5.1,<5.0a0|>=4.5.0,<5.0a0|>=4.1.0,<5.0a0|>=4.0.10,<5.0a0|>=4.0.9,<5.0a0|>=4.0.8,<5.0a0']
# pillow -> lcms2[version='>=2.12,<3.0a0'] -> libtiff[version='>=4.0.10,<4.5.0a0|>=4.1.0,<4.5.0a0|>=4.2.0,<4.5.0a0|>=4.0.9,<4.5.0a0']
# pillow -> libtiff[version='4.*|4.0.*|>=4.0.10,<4.4.0a0|>=4.1.0,<4.4.0a0|>=4.2.0,<4.4.0a0|>=4.3.0,<4.4.0a0|>=4.3.0,<4.5.0a0|>=4.4.0,<4.5.0a0|>=4.5.0,<4.6.0a0|>=4.5.1,<4.6.0a0|>=4.6.0,<4.8.0a0|>=4.7.0,<4.8.0a0|>=4.0.9,<4.4.0a0|>=4.0.8,<4.0.10|>=4.0.3,<4.0.8|4.0.6|>=4.2.0,<5.0a0|>=4.5.1,<5.0a0|>=4.5.0,<5.0a0|>=4.1.0,<5.0a0|>=4.0.10,<5.0a0|>=4.0.9,<5.0a0|>=4.0.8,<5.0a0']
#
# Package numexpr conflicts for:
# numexpr
# rdkit -> pandas -> numexpr[version='>=2.6.8|>=2.7.0|>=2.7.1|>=2.7.3|>=2.8.0|>=2.8.4']
# pandas -> numexpr[version='>=2.6.8|>=2.7.0|>=2.7.1|>=2.7.3|>=2.8.0|>=2.8.4']
#
# Package backports conflicts for:
# importlib_metadata -> configparser[version='>=3.5'] -> backports
# importlib-metadata -> configparser[version='>=3.5'] -> backports
#
# Package flit-core conflicts for:
# flit-core
# importlib-metadata -> typing_extensions[version='>=3.6.4'] -> flit-core[version='>=3.6,<4']
# typing_extensions -> flit-core[version='>=3.6,<4']
#
# Package brotli conflicts for:
# requests -> urllib3[version='>=1.21.1,<3'] -> brotli[version='>=1.0.9']
# urllib3 -> brotli[version='>=1.0.9']
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks
# requests -> urllib3[version='>=1.21.1,<3'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package openblas-devel conflicts for:
# blas -> openblas -> openblas-devel[version='0.3.10|0.3.13|0.3.17|0.3.18|0.3.20|0.3.20|0.3.21|0.3.6|0.3.6|0.3.6|0.3.3|0.3.3|0.3.3|>=0.3.2,<0.3.3.0a0|>=0.2.20,<0.2.21.0a0',build='1|3|0|1|0|h06a4308_0|h06a4308_0|h06a4308_0|h06a4308_1|h06a4308_1|h06a4308_0|2|2']
# numpy -> openblas[version='>=0.3.3,<0.3.4.0a0'] -> openblas-devel[version='0.3.10|0.3.13|0.3.17|0.3.18|0.3.20|0.3.20|0.3.21|0.3.3|>=0.2.20,<0.2.21.0a0|0.3.6|0.3.6|0.3.6|>=0.3.2,<0.3.3.0a0',build='1|0|h06a4308_0|h06a4308_1|h06a4308_0|1|3|2|h06a4308_0|h06a4308_1|h06a4308_0|2|0']
#
# Package lcms2 conflicts for:
# pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0|>=2.14,<3.0a0|>=2.15,<3.0a0|>=2.16,<3.0a0']
# rdkit -> pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0|>=2.14,<3.0a0|>=2.15,<3.0a0|>=2.16,<3.0a0']
# lcms2
#
# Package libboost-devel conflicts for:
# boost-cpp -> libboost-devel[version='1.82.0|1.82.0|1.82.0|1.82.0|1.82.0|1.83.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.85.0',build='h00ab1b0_2|h00ab1b0_3|h00ab1b0_4|h00ab1b0_6|h00ab1b0_0|h00ab1b0_1|h00ab1b0_2|h00ab1b0_3|h00ab1b0_5|h1a2810e_6|h00ab1b0_0|h00ab1b0_2|h00ab1b0_3|h00ab1b0_4|h00ab1b0_1|h1a2810e_7|h00ab1b0_4|h00ab1b0_0|h00ab1b0_5']
# boost -> libboost-python-devel==1.85.0=py39he8689d4_4 -> libboost-devel[version='1.82.0|1.82.0|1.82.0|1.82.0|1.82.0|1.83.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.84.0|1.85.0',build='h00ab1b0_2|h00ab1b0_3|h00ab1b0_4|h00ab1b0_6|h00ab1b0_0|h00ab1b0_1|h00ab1b0_2|h00ab1b0_3|h00ab1b0_5|h1a2810e_6|h00ab1b0_0|h00ab1b0_2|h00ab1b0_3|h00ab1b0_4|h00ab1b0_1|h1a2810e_7|h00ab1b0_4|h00ab1b0_0|h00ab1b0_5']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.35=0
#   - feature:/linux-64::__unix==0=0
#   - feature:|@/linux-64::__glibc==2.35=0
#   - feature:|@/linux-64::__unix==0=0
#   - asn1crypto -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - blas -> __glibc[version='>=2.17,<3.0.a0']
#   - blas -> libgfortran-ng -> __glibc[version='>=2.17|>=2.28,<3.0.a0']
#   - boost -> numpy[version='>=1.19,<3'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - boost-cpp -> bzip2[version='>=1.0.8,<2.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - bottleneck -> __glibc[version='>=2.17,<3.0.a0']
#   - bottleneck -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> __glibc[version='>=2.17,<3.0.a0']
#   - bzip2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> __glibc[version='>=2.17,<3.0.a0']
#   - cairo -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - certifi -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - cffi -> __glibc[version='>=2.17,<3.0.a0']
#   - cffi -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - chardet -> python[version='>=3.12,<3.13.0a0'] -> __glibc[version='>=2.17,<3.0.a0']
#   - conda-package-handling -> python[version='>=3.9'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - conda[version='>=23.1.0'] -> frozendict[version='>=2.4.2'] -> __glibc[version='>=2.17,<3.0.a0']
#   - cryptography -> __glibc[version='>=2.17,<3.0.a0']
#   - cryptography -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - flit-core -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - fontconfig -> __glibc[version='>=2.17,<3.0.a0']
#   - fontconfig -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - freetype -> libpng[version='>=1.6.39,<1.7.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - glib -> __glibc[version='>=2.17,<3.0.a0']
#   - glib -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - icu -> __glibc[version='>=2.17,<3.0.a0']
#   - icu -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - idna -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - importlib-metadata -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> __glibc[version='>=2.17,<3.0.a0']
#   - intel-openmp -> libffi[version='>=3.4,<3.5'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - jpeg -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> __glibc[version='>=2.17,<3.0.a0']
#   - lcms2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ld_impl_linux-64 -> __glibc[version='>=2.17,<3.0.a0']
#   - libboost -> __glibc[version='>=2.17,<3.0.a0']
#   - libboost -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - libedit -> __glibc[version='>=2.17,<3.0.a0']
#   - libedit -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> __glibc[version='>=2.17,<3.0.a0']
#   - libffi -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libpng -> __glibc[version='>=2.17,<3.0.a0']
#   - libpng -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> __glibc[version='>=2.17,<3.0.a0']
#   - libtiff -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> __glibc[version='>=2.17,<3.0.a0']
#   - libxcb -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> __glibc[version='>=2.17,<3.0.a0']
#   - libxml2 -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - mkl -> __glibc[version='>=2.17,<3.0.a0|>=2.28,<3.0.a0']
#   - mkl -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - mkl-service -> __glibc[version='>=2.17,<3.0.a0']
#   - mkl-service -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - mkl_fft -> __glibc[version='>=2.17,<3.0.a0']
#   - mkl_fft -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17|>=2.28,<3.0.a0']
#   - mkl_random -> __glibc[version='>=2.17,<3.0.a0']
#   - mkl_random -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17|>=2.28,<3.0.a0']
#   - ncurses -> __glibc[version='>=2.17,<3.0.a0']
#   - ncurses -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - numexpr -> __glibc[version='>=2.17,<3.0.a0']
#   - numexpr -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - numpy -> __glibc[version='>=2.17,<3.0.a0']
#   - numpy -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17|>=2.28,<3.0.a0']
#   - numpy-base -> blas=[build=openblas] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - olefile -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - openssl -> __glibc[version='>=2.17,<3.0.a0']
#   - openssl -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - packaging -> python[version='>=3.8'] -> __glibc[version='>=2.17,<3.0.a0']
#   - pandas -> __glibc[version='>=2.17,<3.0.a0']
#   - pandas -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pillow -> __glibc[version='>=2.17,<3.0.a0']
#   - pillow -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - pixman -> __glibc[version='>=2.17,<3.0.a0']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pluggy -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - py-boost -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - pycosat -> __glibc[version='>=2.17,<3.0.a0']
#   - pycosat -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - pycparser -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - pyopenssl -> cryptography[version='>=41.0.5,<45'] -> __glibc[version='>=2.17,<3.0.a0']
#   - pysocks -> __unix
#   - pysocks -> __win
#   - pysocks -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - python-dateutil -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - python=3.9 -> __glibc[version='>=2.17,<3.0.a0']
#   - python=3.9 -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - pytz -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - rdkit -> __glibc[version='>=2.17,<3.0.a0']
#   - rdkit -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - readline -> ncurses[version='>=6.3,<7.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - requests -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - ruamel.yaml -> __glibc[version='>=2.17,<3.0.a0']
#   - ruamel.yaml -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - ruamel.yaml.clib -> __glibc[version='>=2.17,<3.0.a0']
#   - ruamel.yaml.clib -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml -> python[version='>=3.10,<3.11.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - setuptools -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - six -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - sqlite -> __glibc[version='>=2.17,<3.0.a0']
#   - sqlite -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libzlib[version='>=1.2.13,<2.0.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - toolz -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - tqdm -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - typing_extensions -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - urllib3 -> brotli-python[version='>=1.0.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> __unix
#   - urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> __win
#   - wheel -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - xz -> __glibc[version='>=2.17,<3.0.a0']
#   - xz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=9.4.0'] -> __glibc[version='>=2.17']
#   - zipp -> python[version='>=3.9'] -> __glibc[version='>=2.17,<3.0.a0']
#   - zlib -> __glibc[version='>=2.17,<3.0.a0']
#   - zlib -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#   - zstd -> __glibc[version='>=2.17,<3.0.a0']
#   - zstd -> libgcc-ng[version='>=10.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.35
#
#
# Collecting rdkit
#   Downloading rdkit-2023.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.5 MB)
#      |████████████████████████████████| 29.5 MB 1.3 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/site-packages (from rdkit) (8.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from rdkit) (1.21.5)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.2

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
# Import necessary libraries
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
import numpy as np

# Download the dataset if it's not already present
import os
if not os.path.exists('acetylcholinesterase_03_bioactivity_data_curated.csv'):
    ! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_03_bioactivity_data_curated.csv

# Assuming 'acetylcholinesterase_03_bioactivity_data_curated.csv' is in the current directory
df = pd.read_csv('acetylcholinesterase_03_bioactivity_data_curated.csv')

# Drop the 'canonical_smiles' column and store it in a separate variable
df_no_smiles = df.drop(columns='canonical_smiles')
smiles = df['canonical_smiles']

# Clean the SMILES data (as before) and create a new dataframe with cleaned SMILES
smiles = []
for i in df.canonical_smiles.tolist():
    cpd = str(i).split('.')
    cpd_longest = max(cpd, key=len)
    smiles.append(cpd_longest)
smiles = pd.Series(smiles, name='canonical_smiles')
df_clean_smiles = pd.concat([df_no_smiles, smiles], axis=1)

# Now you can call the lipinski function
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW    LogP  NumHDonors  NumHAcceptors
# 0     312.325  2.8032         0.0            6.0
# 1     376.913  4.5546         0.0            5.0
# 2     426.851  5.3574         0.0            5.0
# 3     404.845  4.7069         0.0            5.0
# 4     346.334  3.0953         0.0            6.0
# ...       ...     ...         ...            ...
# 6637  301.298  2.0110         4.0            6.0
# 6638  105.093 -1.6094         3.0            3.0
# 6639  401.474  2.9571         3.0            5.0
# 6640  387.447  2.6149         4.0            5.0
# 6641  388.431  3.0419         3.0            5.0
#
# [6642 rows x 4 columns]

# %%
df_lipinski
# Out:
#            MW    LogP  NumHDonors  NumHAcceptors
# 0     312.325  2.8032         0.0            6.0
# 1     376.913  4.5546         0.0            5.0
# 2     426.851  5.3574         0.0            5.0
# 3     404.845  4.7069         0.0            5.0
# 4     346.334  3.0953         0.0            6.0
# ...       ...     ...         ...            ...
# 6637  301.298  2.0110         4.0            6.0
# 6638  105.093 -1.6094         3.0            3.0
# 6639  401.474  2.9571         3.0            5.0
# 6640  387.447  2.6149         4.0            5.0
# 6641  388.431  3.0419         3.0            5.0
#
# [6642 rows x 4 columns]

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#       standard_value         class
# 0              750.0        active
# 1              100.0        active
# 2            50000.0      inactive
# 3              300.0        active
# 4              800.0        active
# ...              ...           ...
# 6637         46000.0      inactive
# 6638         38310.0      inactive
# 6639          1710.0  intermediate
# 6640         10000.0      inactive
# 6641         10000.0      inactive
#
# [6642 rows x 4 columns]

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#       standard_value         class       MW    LogP  NumHDonors  NumHAcceptors
# 0              750.0        active  312.325  2.8032         0.0            6.0
# 1              100.0        active  376.913  4.5546         0.0            5.0
# 2            50000.0      inactive  426.851  5.3574         0.0            5.0
# 3              300.0        active  404.845  4.7069         0.0            5.0
# 4              800.0        active  346.334  3.0953         0.0            6.0
# ...              ...           ...      ...     ...         ...            ...
# 6637         46000.0      inactive  301.298  2.0110         4.0            6.0
# 6638         38310.0      inactive  105.093 -1.6094         3.0            3.0
# 6639          1710.0  intermediate  401.474  2.9571         3.0            5.0
# 6640         10000.0      inactive  387.447  2.6149         4.0            5.0
# 6641         10000.0      inactive  388.431  3.0419         3.0            5.0
#
# [6642 rows x 8 columns]

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)

    return x

# %%
df_combined.standard_value.describe()
# Out:
# count    6.642000e+03
# mean     1.026835e+05
# std      8.884597e+05
# min      0.000000e+00
# 25%      1.592500e+02
# 50%      2.600000e+03
# 75%      1.713000e+04
# max      4.960000e+07
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)

    return x

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', axis=1) # Changed '1' to 'axis=1'

    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#              class       MW    LogP  NumHDonors  NumHAcceptors  \
# 0           active  312.325  2.8032         0.0            6.0
# 1           active  376.913  4.5546         0.0            5.0
# 2         inactive  426.851  5.3574         0.0            5.0
# 3           active  404.845  4.7069         0.0            5.0
# 4           active  346.334  3.0953         0.0            6.0
# ...            ...      ...     ...         ...            ...
# 6637      inactive  301.298  2.0110         4.0            6.0
# 6638      inactive  105.093 -1.6094         3.0            3.0
# 6639  intermediate  401.474  2.9571         3.0            5.0
# 6640      inactive  387.447  2.6149         4.0            5.0
# 6641      inactive  388.431  3.0419         3.0            5.0
#
#       standard_value_norm
# 0                   750.0
# 1                   100.0
# 2                 50000.0
# 3                   300.0
# 4                   800.0
# ...                   ...
# 6637              46000.0
# 6638              38310.0
# 6639               1710.0
# 6640              10000.0
# 6641              10000.0
#
# [6642 rows x 8 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    6.642000e+03
# mean     1.026835e+05
# std      8.884597e+05
# min      0.000000e+00
# 25%      1.592500e+02
# 50%      2.600000e+03
# 75%      1.713000e+04
# max      4.960000e+07
# Name: standard_value_norm, dtype: float64

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop(columns=['standard_value_norm']) # Use 'columns' keyword argument

    return x

# %%
df_final = pIC50(df_norm)
df_final
# Out:
# <ipython-input-59-7f5adc5b59de>:6: RuntimeWarning: divide by zero encountered in log10
#   pIC50.append(-np.log10(molar))
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6639      CHEMBL5395312  CN1CCN(c2ccc(C(=O)Nc3cc(-c4nc5ccccc5[nH]4)n[nH...
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#              class       MW    LogP  NumHDonors  NumHAcceptors     pIC50
# 0           active  312.325  2.8032         0.0            6.0  6.124939
# 1           active  376.913  4.5546         0.0            5.0  7.000000
# 2         inactive  426.851  5.3574         0.0            5.0  4.301030
# 3           active  404.845  4.7069         0.0            5.0  6.522879
# 4           active  346.334  3.0953         0.0            6.0  6.096910
# ...            ...      ...     ...         ...            ...       ...
# 6637      inactive  301.298  2.0110         4.0            6.0  4.337242
# 6638      inactive  105.093 -1.6094         3.0            3.0  4.416688
# 6639  intermediate  401.474  2.9571         3.0            5.0  5.767004
# 6640      inactive  387.447  2.6149         4.0            5.0  5.000000
# 6641      inactive  388.431  3.0419         3.0            5.0  5.000000
#
# [6642 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    6642.000000
# mean             inf
# std              NaN
# min         1.304518
# 25%         4.766243
# 50%         5.585027
# 75%         6.797922
# max              inf
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6636      CHEMBL5435795                      O=Cc1ccc2n1CCc1cc(O)c(O)cc1C2
# 6637      CHEMBL5398421            COc1cc(O)c2c(c1)C(=O)c1cc(O)c(O)cc1CCN2
# 6638        CHEMBL11298                                  N[C@@H](CO)C(=O)O
# 6640      CHEMBL5399112  O=C(Nc1cc(-c2nc3ccccc3[nH]2)n[nH]1)c1ccc(N2CCN...
# 6641      CHEMBL5402411  O=C(Nc1cc(-c2nc3ccccc3[nH]2)[nH]n1)c1ccc(N2CCO...
#
#          class       MW    LogP  NumHDonors  NumHAcceptors     pIC50
# 0       active  312.325  2.8032         0.0            6.0  6.124939
# 1       active  376.913  4.5546         0.0            5.0  7.000000
# 2     inactive  426.851  5.3574         0.0            5.0  4.301030
# 3       active  404.845  4.7069         0.0            5.0  6.522879
# 4       active  346.334  3.0953         0.0            6.0  6.096910
# ...        ...      ...     ...         ...            ...       ...
# 6636  inactive  243.262  1.8587         2.0            4.0  4.233810
# 6637  inactive  301.298  2.0110         4.0            6.0  4.337242
# 6638  inactive  105.093 -1.6094         3.0            3.0  4.416688
# 6640  inactive  387.447  2.6149         4.0            5.0  5.000000
# 6641  inactive  388.431  3.0419         3.0            5.0  5.000000
#
# [4969 rows x 8 columns]

# %%
df_2class.to_csv('acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv')

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

# Replace 'pIC50' with 'pIC50.fillna(0)' or 'pIC50.replace([np.inf, -np.inf], np.nan).fillna(0)'
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:2294: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:2294: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-397388724c67> in <cell line: 0>()
#       7 plt.ylabel('LogP', fontsize=14, fontweight='bold')
#       8 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
# ----> 9 plt.savefig('plot_MW_vs_LogP.pdf')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# -> 1243     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245     return res
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3488                 for ax in self.axes:
#    3489                     _recursively_make_axes_transparent(stack, ax)
# -> 3490             self.canvas.print_figure(fname, **kwargs)
#    3491
#    3492     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, bbox_inches_restore, metadata)
#    2784                 RendererPdf(file, dpi, height, width),
#    2785                 bbox_inches_restore=bbox_inches_restore)
# -> 2786             self.figure.draw(renderer)
#    2787             renderer.finalize()
#    2788             if not isinstance(filename, PdfPages):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py in draw(self, renderer)
#    1015     def draw(self, renderer):
#    1016         self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1017         super().draw(renderer)
#    1018
#    1019
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py in draw(self, renderer)
#     428                     "screen")
#     429
# --> 430             renderer.draw_path_collection(
#     431                 gc, transform.frozen(), paths,
#     432                 self.get_transforms(), offsets, offset_trf,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offset_trans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#    2069
#    2070         if (not can_do_optimization) or (not should_do_optimization):
# -> 2071             return RendererBase.draw_path_collection(
#    2072                 self, gc, master_transform, paths, all_transforms,
#    2073                 offsets, offset_trans, facecolors, edgecolors,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offset_trans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#     247                 transform = transform.frozen()
#     248                 transform.translate(xo, yo)
# --> 249             self.draw_path(gc0, path, transform, rgbFace)
#     250
#     251     def draw_quad_mesh(self, gc, master_transform, meshWidth, meshHeight,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in draw_path(self, gc, path, transform, rgbFace)
#    2021     def draw_path(self, gc, path, transform, rgbFace=None):
#    2022         # docstring inherited
# -> 2023         self.check_gc(gc, rgbFace)
#    2024         self.file.writePath(
#    2025             path, transform,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in check_gc(self, gc, fillcolor)
#    1980         delta = self.gc.delta(gc)
#    1981         if delta:
# -> 1982             self.file.output(*delta)
#    1983
#    1984         # Restore gc to avoid unwanted side effects
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in output(self, *data)
#     871
#     872     def output(self, *data):
# --> 873         self.write(_fill([pdfRepr(x) for x in data]))
#     874         self.write(b'\n')
#     875
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in <listcomp>(.0)
#     871
#     872     def output(self, *data):
# --> 873         self.write(_fill([pdfRepr(x) for x in data]))
#     874         self.write(b'\n')
#     875
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_pdf.py in pdfRepr(obj)
#     309     elif isinstance(obj, (float, np.floating)):
#     310         if not np.isfinite(obj):
# --> 311             raise ValueError("Can only output finite numbers in PDF")
#     312         r = b"%.10f" % obj
#     313         return r.rstrip(b'0').rstrip(b'.')
#
# ValueError: Can only output finite numbers in PDF

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')

# %%
! zip -r results.zip . -i *.csv *.pdf

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh

# %%
! unzip padel.zip

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv

# %%
import pandas as pd

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df3

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5

# %%
! cat molecule.smi | wc -l

# %%
! cat padel.sh

# %%
! bash padel.sh

# %%
! ls -l

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X

# %%
df3_Y = df3['pIC50']
df3_Y

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
X

# %%
Y = df.pIC50
Y

# %%
X.shape

# %%
Y.shape

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)

# %%
X.shape

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape

# %%
X_test.shape, Y_test.shape

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from lazypredict) (8.1.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->lazypredict) (2.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.17.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2025-02-22 08:29:02--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2025-02-22 08:29:03--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# acetylcholinesteras 100%[===================>]   7.98M  --.-KB/s    in 0.1s
#
# 2025-02-22 08:29:03 (67.5 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
import pandas as pd # import pandas and alias it as 'pd'
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
from sklearn.model_selection import train_test_split # Import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Defines and builds the lazyclassifier
# !pip install lazypredict
from lazypredict.Supervised import LazyRegressor # Import LazyRegressor
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.11/dist-packages (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from lazypredict) (8.1.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->lazypredict) (2.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.17.0)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
#  98%|█████████▊| 41/42 [00:58<00:01,  1.14s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003601 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 100%|██████████| 42/42 [00:58<00:00,  1.39s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#  98%|█████████▊| 41/42 [00:50<00:00,  1.11it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003086 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 100%|██████████| 42/42 [00:51<00:00,  1.22s/it]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# DecisionTreeRegressor                        0.86       0.86  0.57        0.19
# ExtraTreeRegressor                           0.86       0.86  0.57        0.22
# ExtraTreesRegressor                          0.86       0.86  0.57        6.97
# GaussianProcessRegressor                     0.86       0.86  0.57        7.07
# RandomForestRegressor                        0.82       0.83  0.64        5.11
# XGBRegressor                                 0.82       0.83  0.65        1.25
# BaggingRegressor                             0.80       0.81  0.67        0.61
# MLPRegressor                                 0.76       0.77  0.75        7.13
# HistGradientBoostingRegressor                0.67       0.69  0.87        1.23
# LGBMRegressor                                0.65       0.67  0.90        0.42
# KNeighborsRegressor                          0.63       0.65  0.92        0.25
# SVR                                          0.56       0.58  1.01        4.12
# NuSVR                                        0.55       0.57  1.02        2.52
# GradientBoostingRegressor                    0.44       0.46  1.14        1.76
# TransformedTargetRegressor                   0.31       0.33  1.27        0.31
# LinearRegression                             0.31       0.33  1.27        0.18
# Ridge                                        0.31       0.33  1.27        0.06
# LassoCV                                      0.30       0.33  1.27        3.96
# ElasticNetCV                                 0.30       0.33  1.27        4.73
# RidgeCV                                      0.30       0.33  1.27        0.22
# SGDRegressor                                 0.30       0.32  1.28        0.17
# BayesianRidge                                0.29       0.32  1.28        0.21
# HuberRegressor                               0.29       0.31  1.29        0.29
# LinearSVR                                    0.27       0.30  1.30        1.02
# LassoLarsCV                                  0.27       0.29  1.31        0.66
# LassoLarsIC                                  0.27       0.29  1.31        0.57
# PoissonRegressor                             0.25       0.28  1.32        0.20
# Lars                                         0.22       0.24  1.35        0.12
# AdaBoostRegressor                            0.20       0.23  1.36        0.80
# OrthogonalMatchingPursuitCV                  0.20       0.23  1.37        0.15
# OrthogonalMatchingPursuit                    0.20       0.23  1.37        0.05
# TweedieRegressor                             0.19       0.22  1.37        0.14
# GammaRegressor                               0.19       0.22  1.37        0.08
# LarsCV                                       0.13       0.16  1.42        0.37
# LassoLars                                   -0.04       0.00  1.55        0.14
# ElasticNet                                  -0.04       0.00  1.55        0.05
# DummyRegressor                              -0.04       0.00  1.55        0.04
# Lasso                                       -0.04       0.00  1.55        0.11
# QuantileRegressor                           -0.05      -0.01  1.56        1.93
# PassiveAggressiveRegressor                  -0.17      -0.13  1.65        0.14
# RANSACRegressor                             -1.30      -1.21  2.31        1.62
# KernelRidge                                -14.25     -13.70  5.95        1.20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_train['Adjusted R-Squared'].plot(kind='hist', bins=20, title='Adjusted R-Squared')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['R-Squared'].plot(kind='hist', bins=20, title='R-Squared')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['RMSE'].plot(kind='hist', bins=20, title='RMSE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['Time Taken'].plot(kind='hist', bins=20, title='Time Taken')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_train.plot(kind='scatter', x='Adjusted R-Squared', y='R-Squared', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_train.plot(kind='scatter', x='R-Squared', y='RMSE', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_train.plot(kind='scatter', x='RMSE', y='Time Taken', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['RMSE']
#   ys = series['Adjusted R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_train.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('Adjusted R-Squared')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['RMSE']
#   ys = series['R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_train.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('R-Squared')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['RMSE']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'RMSE'}, axis=1)
#               .sort_values('RMSE', ascending=True))
#   xs = counted['RMSE']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_train.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Time Taken']
#   ys = series['Adjusted R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_train.sort_values('Time Taken', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Time Taken')
# _ = plt.ylabel('Adjusted R-Squared')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_train['Adjusted R-Squared'].plot(kind='line', figsize=(8, 4), title='Adjusted R-Squared')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['R-Squared'].plot(kind='line', figsize=(8, 4), title='R-Squared')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['RMSE'].plot(kind='line', figsize=(8, 4), title='RMSE')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_train['Time Taken'].plot(kind='line', figsize=(8, 4), title='Time Taken')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.46       0.54  1.06        1.14
# RandomForestRegressor                        0.44       0.52  1.08        5.01
# LGBMRegressor                                0.44       0.52  1.08        0.34
# XGBRegressor                                 0.44       0.52  1.08        1.29
# BaggingRegressor                             0.41       0.49  1.11        0.86
# NuSVR                                        0.39       0.48  1.12        2.41
# SVR                                          0.39       0.48  1.12        2.24
# KNeighborsRegressor                          0.37       0.46  1.14        0.12
# MLPRegressor                                 0.36       0.45  1.15        6.43
# GradientBoostingRegressor                    0.33       0.42  1.18        1.73
# ExtraTreesRegressor                          0.22       0.34  1.27        7.79
# DecisionTreeRegressor                        0.20       0.32  1.28        0.15
# Ridge                                        0.20       0.32  1.28        0.16
# TransformedTargetRegressor                   0.20       0.32  1.28        0.28
# LinearRegression                             0.20       0.32  1.28        0.14
# RidgeCV                                      0.20       0.32  1.28        0.16
# ElasticNetCV                                 0.20       0.32  1.28        3.66
# LassoCV                                      0.20       0.32  1.28        5.03
# ExtraTreeRegressor                           0.20       0.32  1.29        0.15
# SGDRegressor                                 0.19       0.31  1.29        0.16
# BayesianRidge                                0.19       0.31  1.29        0.30
# HuberRegressor                               0.19       0.31  1.29        0.28
# LassoLarsCV                                  0.17       0.30  1.30        0.31
# LassoLarsIC                                  0.17       0.30  1.30        0.22
# LinearSVR                                    0.16       0.28  1.32        0.78
# PoissonRegressor                             0.16       0.28  1.32        0.08
# OrthogonalMatchingPursuit                    0.11       0.24  1.36        0.04
# OrthogonalMatchingPursuitCV                  0.11       0.24  1.36        0.10
# Lars                                         0.10       0.23  1.36        0.12
# GammaRegressor                               0.08       0.22  1.37        0.05
# TweedieRegressor                             0.08       0.22  1.38        0.13
# AdaBoostRegressor                            0.07       0.21  1.38        0.73
# LarsCV                                       0.02       0.16  1.42        0.53
# Lasso                                       -0.17      -0.00  1.55        0.10
# ElasticNet                                  -0.17      -0.00  1.55        0.04
# LassoLars                                   -0.17      -0.00  1.55        0.11
# DummyRegressor                              -0.17      -0.00  1.55        0.03
# QuantileRegressor                           -0.19      -0.02  1.57        1.25
# PassiveAggressiveRegressor                  -0.42      -0.22  1.71        0.11
# RANSACRegressor                             -1.56      -1.19  2.30        1.55
# GaussianProcessRegressor                    -6.02      -4.99  3.80        3.91
# KernelRidge                                -16.36     -13.82  5.98        1.06
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_test['Adjusted R-Squared'].plot(kind='hist', bins=20, title='Adjusted R-Squared')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['R-Squared'].plot(kind='hist', bins=20, title='R-Squared')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['RMSE'].plot(kind='hist', bins=20, title='RMSE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['Time Taken'].plot(kind='hist', bins=20, title='Time Taken')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_test.plot(kind='scatter', x='Adjusted R-Squared', y='R-Squared', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_test.plot(kind='scatter', x='R-Squared', y='RMSE', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# models_test.plot(kind='scatter', x='RMSE', y='Time Taken', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['RMSE']
#   ys = series['Adjusted R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_test.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('Adjusted R-Squared')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['RMSE']
#   ys = series['R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_test.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('R-Squared')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['RMSE']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'RMSE'}, axis=1)
#               .sort_values('RMSE', ascending=True))
#   xs = counted['RMSE']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_test.sort_values('RMSE', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('RMSE')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Time Taken']
#   ys = series['Adjusted R-Squared']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = models_test.sort_values('Time Taken', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Time Taken')
# _ = plt.ylabel('Adjusted R-Squared')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# models_test['Adjusted R-Squared'].plot(kind='line', figsize=(8, 4), title='Adjusted R-Squared')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['R-Squared'].plot(kind='line', figsize=(8, 4), title='R-Squared')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['RMSE'].plot(kind='line', figsize=(8, 4), title='RMSE')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# models_test['Time Taken'].plot(kind='line', figsize=(8, 4), title='Time Taken')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
